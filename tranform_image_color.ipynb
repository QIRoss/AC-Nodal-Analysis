# %% [markdown]
# <a href="https://colab.research.google.com/github/QIRoss/AC-Nodal-Analysis/blob/main/tranform_image_color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar bibliotecas necessárias
import cv2
import matplotlib.pyplot as plt

# %%
# Fazer upload da imagem no Google Colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c607b5a7-e4c7-40e6-857f-a99a4378b664" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c607b5a7-e4c7-40e6-857f-a99a4378b664">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Ler a imagem (substitua 'imagem.jpg' pelo nome do arquivo carregado)
image_path = list(uploaded.keys())[0]
image = cv2.imread(image_path)

# %%
# Converter a imagem para níveis de cinza
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite('2024-12-30 01-00-51.png', gray_image)
# Out:
# True

# %%
plt.figure(figsize=(10, 5))
plt.imshow(gray_image, cmap='gray')
plt.title('Imagem em Níveis de Cinza')
plt.axis('off')
plt.show()

# %%
# Tarefa 2: Converter a imagem para binária (preto e branco)
_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# %%
cv2.imwrite('imagem_binaria.jpg', binary_image)
# Out:
# True

# %%
plt.figure(figsize=(10, 5))
plt.imshow(binary_image, cmap='gray')
plt.title('Imagem Binária (Preto e Branco)')
plt.axis('off')
plt.show()

# %%
# utilizei 127 e 255 ao invés de 0 e 255 para melhorar a foto. Fotos estouradas e não profissionais provavelmente serão mais difíceis de funcionar corretamente.
